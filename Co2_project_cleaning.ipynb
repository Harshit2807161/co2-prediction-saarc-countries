# %%
import numpy as np
import pandas as pd
import datetime

# %%
co2df = pd.read_csv("final_cleaned_data_yearly.csv",index_col = 0)

# %%
co2df.head()
# Out:
#        country  year iso_code  population           gdp  cement_co2    co2  \
# 0  Afghanistan  1949      AFG     7356890  9.421400e+09       0.018  0.015
# 1  Afghanistan  1950      AFG     7480464  9.421400e+09       0.018  0.084
# 2  Afghanistan  1951      AFG     7571542  9.692280e+09       0.018  0.092
# 3  Afghanistan  1952      AFG     7667534  1.001733e+10       0.018  0.092
# 4  Afghanistan  1953      AFG     7764549  1.063052e+10       0.018  0.106
#
#    co2_including_luc  coal_co2  cumulative_cement_co2  ...  \
# 0              8.039     0.015                  0.018  ...
# 1              8.585     0.021                  0.018  ...
# 2              9.142     0.026                  0.018  ...
# 3              9.948     0.032                  0.018  ...
# 4             10.915     0.038                  0.018  ...
#
#    share_global_cumulative_luc_co2  share_global_cumulative_oil_co2  \
# 0                            0.140                            0.000
# ...

# %%
co2df['country'].unique()
# Out:
# array(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Nepal',
#        'Pakistan', 'Sri Lanka'], dtype=object)

# %%
co2df.isna().sum()
# Out:
# country                                      0
# year                                         0
# iso_code                                     0
# population                                   0
# gdp                                          0
# cement_co2                                   0
# co2                                          0
# co2_including_luc                            0
# coal_co2                                     0
# cumulative_cement_co2                        0
# cumulative_co2                               0
# cumulative_co2_including_luc                 0
# cumulative_coal_co2                          0
# cumulative_luc_co2                           0
# cumulative_oil_co2                           0
# land_use_change_co2                          0
# oil_co2                                      0
# share_global_cement_co2                      0
# share_global_co2                             0
# share_global_co2_including_luc               0
# ...

# %%
co2df.shape
# Out:
# (574, 35)

# %%
#coun = 'Sri Lanka'

# %%
#co2df.loc[(co2df.country==coun)] = co2df.loc[(co2df.country==coun)].ffill()
#co2df.loc[(co2df.country==coun)] = co2df.loc[(co2df.country==coun)].bfill()

# %%
#new_df = co2df.interpolate(method = "polynomial",order = 3,limit_direction = 'both')

# %%
# Out:
#      country   year  iso_code  population    gdp  cement_co2    co2  \
# 0      False  False     False       False  False       False  False
# 1      False  False     False       False  False       False  False
# 2      False  False     False       False  False       False  False
# 3      False  False     False       False  False       False  False
# 4      False  False     False       False  False       False  False
# ..       ...    ...       ...         ...    ...         ...    ...
# 620    False  False     False       False  False       False  False
# 621    False  False     False       False  False       False  False
# 622    False  False     False       False  False       False  False
# 623    False  False     False       False  False       False  False
# 624    False  False     False       False  False       False  False
#
#      co2_including_luc  coal_co2  cumulative_cement_co2  ...  \
# 0                False     False                  False  ...
# ...

# %%
#co2df.to_csv("final_cleaned_data_yearly.csv")

# %%
co2df.isna().sum()
# Out:
# country                                      0
# year                                         0
# iso_code                                     0
# population                                   0
# gdp                                          0
# cement_co2                                   0
# co2                                          0
# co2_including_luc                            0
# coal_co2                                     0
# cumulative_cement_co2                        0
# cumulative_co2                               0
# cumulative_co2_including_luc                 0
# cumulative_coal_co2                          0
# cumulative_luc_co2                           0
# cumulative_oil_co2                           0
# land_use_change_co2                          0
# oil_co2                                      0
# share_global_cement_co2                      0
# share_global_co2                             0
# share_global_co2_including_luc               0
# ...

# %%
co2df['year']
# Out:
# 0      1949
# 1      1950
# 2      1951
# 3      1952
# 4      1953
#        ...
# 569    2017
# 570    2018
# 571    2019
# 572    2020
# 573    2021
# Name: year, Length: 574, dtype: int64

# %%
input = '2021'
format = '%Y'
 
# convert from string format to datetime format
c = datetime.strptime(input, format)
c
# Out:
# datetime.datetime(2021, 1, 1, 0, 0)

# %%
co2df['year'] = pd.to_datetime(co2df['year'], format='%Y')

# %%
co2df = co2df.set_index('year')

# %%
l = ['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Nepal',
       'Pakistan', 'Sri Lanka']

# %%
afgh = co2df.loc[(co2df.country=='Afghanistan')].resample('M').ffill()
bang = co2df.loc[(co2df.country=='Bangladesh')].resample('M').ffill()
bhutan = co2df.loc[(co2df.country=='Bhutan')].resample('M').ffill()
india = co2df.loc[(co2df.country=='India')].resample('M').ffill()
nepal = co2df.loc[(co2df.country=='Nepal')].resample('M').ffill()
pakistan = co2df.loc[(co2df.country=='Pakistan')].resample('M').ffill()
srilanka = co2df.loc[(co2df.country=='Sri Lanka')].resample('M').ffill()

# %%
final_monthly_data = pd.concat([afgh,bang,bhutan,india,nepal,pakistan,srilanka])

# %%
final_monthly_data.to_csv("input_data_clean_monthly.csv")

# %%
final_monthly_data
# Out:
#                 country iso_code  population           gdp  cement_co2  \
# year
# 1949-01-31  Afghanistan      AFG     7356890  9.421400e+09       0.018
# 1949-02-28  Afghanistan      AFG     7356890  9.421400e+09       0.018
# 1949-03-31  Afghanistan      AFG     7356890  9.421400e+09       0.018
# 1949-04-30  Afghanistan      AFG     7356890  9.421400e+09       0.018
# 1949-05-31  Afghanistan      AFG     7356890  9.421400e+09       0.018
# ...                 ...      ...         ...           ...         ...
# 2020-09-30    Sri Lanka      LKA    21715076  2.530000e+11       1.511
# 2020-10-31    Sri Lanka      LKA    21715076  2.530000e+11       1.511
# 2020-11-30    Sri Lanka      LKA    21715076  2.530000e+11       1.511
# 2020-12-31    Sri Lanka      LKA    21715076  2.530000e+11       1.511
# 2021-01-31    Sri Lanka      LKA    21773438  2.530000e+11       1.511
#
#                co2  co2_including_luc  coal_co2  cumulative_cement_co2  \
# year
# ...

# %%
mnc = co2df.loc[(co2df.country=='Afghanistan')]

# %%
import matplotlib.pyplot as plt
import pandas as pd
 
timeseries = mnc[["output_co2_production"]].values.astype('float32')
 
plt.plot(timeseries)
plt.show()
